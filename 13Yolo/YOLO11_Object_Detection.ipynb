# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Sanala Yoloyu kur
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/107.7 GB disk)

# %%
#Klasörleri oluştur
# !mkdir /content/drive/MyDrive/YoloProjectObjectDetection
# !mkdir /content/drive/MyDrive/YoloProjectObjectDetection/runs
# !mkdir /content/drive/MyDrive/YoloProjectObjectDetection/weights

# %%
# %cd /content/drive/MyDrive/YoloProjectObjectDetection
# %pwd
from ultralytics import settings
#YoloV11 ayarlarını değiştir. Dataset, runs ve weights klasörlerini
#google drive içindeki local klasörler olarak ayarla
#Bu ayar yapılmazsa sanal'da content içine atar.
settings["datasets_dir"]="/content/drive/MyDrive/datasets" #change dataset dir
settings["runs_dir"]="/content/drive/MyDrive/YoloProjectObjectDetection/runs" #change run dir
settings["weights_dir"]="/content/drive/MyDrive/YoloProjectObjectDetection/weights" #change weights dir
# View all settings
print(settings)
# Out:
# /content/drive/MyDrive/YoloProjectObjectDetection
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/drive/MyDrive/datasets",
#   "weights_dir": "/content/drive/MyDrive/YoloProjectObjectDetection/weights",
#   "runs_dir": "/content/drive/MyDrive/YoloProjectObjectDetection/runs",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }

# %% [markdown]
# # 1. Predict For Object Detection
#
# YOLO11 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 66.7MB/s]
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 49.2k/49.2k [00:00<00:00, 4.44MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 192.5ms
# Speed: 13.1ms preprocess, 192.5ms inference, 33.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/drive/MyDrive/YoloProjectObjectDetection/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLO11 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLO11 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Validate YOLO11n on COCO8 val
# !yolo val model=yolo11n.pt data=coco8.yaml
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/content/drive/MyDrive/datasets/coco8/images/val'
# ...
# 100% 433k/433k [00:00<00:00, 9.79MB/s]
# Unzipping /content/drive/MyDrive/datasets/coco8.zip to /content/drive/MyDrive/datasets/coco8...: 100% 25/25 [00:00<00:00, 138.25file/s]
# Dataset download success ✅ (0.6s), saved to /content/drive/MyDrive/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 13.9MB/s]
# val: Scanning /content/drive/MyDrive/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 45.62it/s]
# val: New cache created: /content/drive/MyDrive/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.18s/it]
# ...

# %%
# Train Manual
# !yolo train model=yolo11n.pt data=custom1.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 78.6MB/s]
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
#Validation yapılıyor

# !yolo val model=runs/detect/train2/weights/best.pt data=/content/drive/MyDrive/YoloProjectObjectDetection/custom1.yaml
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/MyDrive/datasets/ObjectDetection/labels/val.cache... 31 images, 0 backgrounds, 0 corrupt: 100% 31/31 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:14<00:00,  7.01s/it]
#                    all         31         31      0.998          1      0.995      0.862
# Speed: 10.7ms preprocess, 273.2ms inference, 0.0ms loss, 6.0ms postprocess per image
# Results saved to /content/drive/MyDrive/YoloProjectObjectDetection/runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#val klasöründeki resimler predict ediliyor

# !yolo predict model=runs/detect/train2/weights/best.pt source="/content/drive/MyDrive/datasets/ObjectDetection/images/val" imgsz=640 save_txt=True save=True save_crop=True  exist_ok=True conf=0.5
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/31 /content/drive/MyDrive/datasets/ObjectDetection/images/val/drishtiGS_071.png: 576x640 1 optic, 229.3ms
# image 2/31 /content/drive/MyDrive/datasets/ObjectDetection/images/val/drishtiGS_072.png: 576x640 1 optic, 183.6ms
# image 3/31 /content/drive/MyDrive/datasets/ObjectDetection/images/val/drishtiGS_073.png: 544x640 1 optic, 173.5ms
# image 4/31 /content/drive/MyDrive/datasets/ObjectDetection/images/val/drishtiGS_074.png: 576x640 1 optic, 186.9ms
# image 5/31 /content/drive/MyDrive/datasets/ObjectDetection/images/val/drishtiGS_075.png: 480x640 1 optic, 235.2ms
# image 6/31 /content/drive/MyDrive/datasets/ObjectDetection/images/val/drishtiGS_076.png: 576x640 1 optic, 266.2ms
# image 7/31 /content/drive/MyDrive/datasets/ObjectDetection/images/val/drishtiGS_077.png: 576x640 1 optic, 264.6ms
# ...

# %% [markdown]
# # 6. Tasks
#
# YOLO11 can train, val, predict and export models for the most common tasks in vision AI: [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/). See [YOLO11 Tasks Docs](https://docs.ultralytics.com/tasks/) for more information.
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 2. Segmentation
#
# YOLO11 _segmentation_ models use the `-seg` suffix, i.e. `yolo11n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Build a new model from YAML and start training from scratch
#!yolo segment train data=/content/drive/MyDrive/YoloProject1/custom1.yaml model=yolo11n-seg.yaml epochs=5 imgsz=640
# Start training from a pretrained *.pt model
# !yolo segment train data=customsegment.yaml model=yolo11n-seg.pt epochs=500 imgsz=640

# Build a new model from YAML, transfer pretrained weights to it and start training
#!yolo segment train data=/content/drive/MyDrive/YoloProject1/custom1.yaml model=yolo11n-seg.yaml pretrained=yolo11n-seg.pt epochs=500 imgsz=640
# Out:
# ...
# 100% 5.90M/5.90M [00:00<00:00, 81.9MB/s]
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
#----Predict Segmentation
# !yolo predict model=runs/segment/train/weights/best.pt source="/content/drive/MyDrive/datasets/optic-seg/images/val" imgsz=640 save_txt=True save=True save_crop=True  exist_ok=True
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n-seg summary (fused): 265 layers, 2,834,763 parameters, 0 gradients, 10.2 GFLOPs
#
# image 1/4 /content/drive/MyDrive/datasets/optic-seg/images/val/005.jpg: 544x640 1 optic, 302.8ms
# image 2/4 /content/drive/MyDrive/datasets/optic-seg/images/val/006.jpg: 544x640 1 optic, 249.6ms
# image 3/4 /content/drive/MyDrive/datasets/optic-seg/images/val/007.jpg: 544x640 1 optic, 237.0ms
# image 4/4 /content/drive/MyDrive/datasets/optic-seg/images/val/008.jpg: 544x640 1 optic, 230.3ms
# Speed: 5.2ms preprocess, 254.9ms inference, 6.5ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to /content/drive/MyDrive/YoloProjectObjectDetection/runs/segment/predict
# 4 labels saved to /content/drive/MyDrive/YoloProjectObjectDetection/runs/segment/predict/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#Validation Results
# !yolo val model=runs/segment/train/weights/best.pt data=customsegment.yaml
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n-seg summary (fused): 265 layers, 2,834,763 parameters, 0 gradients, 10.2 GFLOPs
# val: Scanning /content/drive/MyDrive/datasets/optic-seg/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.81s/it]
#                    all          4          4      0.987          1      0.995      0.846      0.987          1      0.995      0.758
# Speed: 3.6ms preprocess, 281.3ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to /content/drive/MyDrive/YoloProjectObjectDetection/runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## 3. Classification
#
# YOLO11 _classification_ models use the `-cls` suffix, i.e. `yolo11n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLO11n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-cls.pt')  # load a pretrained YOLO classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Pose
#
# YOLO11 _pose_ models use the `-pose` suffix, i.e. `yolo11n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLO11n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-pose.pt')  # load a pretrained YOLO pose model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Oriented Bounding Boxes (OBB)
#
# YOLO11 _OBB_ models use the `-obb` suffix, i.e. `yolo11n-obb.pt` and are pretrained on the DOTA dataset. See [OBB Docs](https://docs.ultralytics.com/tasks/obb/) for full details.

# %%
# Load YOLO11n-obb, train it on DOTA8 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-obb.pt')  # load a pretrained YOLO OBB model
model.train(data='dota8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/boats.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Git clone and run tests on updates branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 45189, done.
# remote: Counting objects: 100% (1524/1524), done.
# remote: Compressing objects: 100% (858/858), done.
# remote: Total 45189 (delta 1078), reused 1006 (delta 662), pack-reused 43665 (from 1)
# Receiving objects: 100% (45189/45189), 38.08 MiB | 24.55 MiB/s, done.
# Resolving deltas: 100% (33537/33537), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done
